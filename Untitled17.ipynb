# %% [markdown]
# <a href="https://colab.research.google.com/github/yuri-biangulo/Projetos-Iniciais-Aprendizagem-Aplicada/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.append('Canada')
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries.insert(0, 'Spain' )
countries

# %%
countries_2 = ['UK', 'Germany', 'Austria']
countries + countries_2
# Out:
# ['Spain',
#  'Spain',
#  'Spain',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Spain',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]
nested_list
# Out:
# [['Spain',
#   'Spain',
#   'Spain',
#   'United States',
#   'India',
#   'China',
#   'Brazil',
#   'Spain',
#   'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.remove('United States')
countries
# Out:
# ['India', 'China', 'Brazil']

# %%
countries.pop(-1)
# Out:
# 'Brazil'

# %%
del countries[0]
countries

# %%
#Sorting a list 
numbers = [4,3,10,7,1,2]
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers = [4,3,10,7,1,2]
numbers.sort(reverse = True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
# Update an Element on a list 
numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
#cOPYING A LIST
countries = ['USA', 'Brasil', 'India']
new_list = countries[:]

# %%
new_list
# Out:
# ['USA', 'Brasil', 'India']

# %%
new_list_2 = countries.copy()

# %%
new_list_2
# Out:
# ['USA', 'Brasil', 'India']

# %%
my_dict = {'key1':'Value1', 'key2':'value2'}
my_data = {'name':'Yuri', 'age': '25'}
my_data
# Out:
# {'age': '25', 'name': 'Yuri'}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Yuri', '25'])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Yuri'), ('age', '25')])

# %%
my_data['height'] = 1.7
my_data
# Out:
# {'age': '25', 'height': 1.7, 'name': 'Yuri'}

# %%
my_data.update({'height':1.8})
my_data
# Out:
# {'age': '25', 'height': 1.8, 'name': 'Yuri'}

# %%
#COPY A DICTIONARY 
new_dict = my_data.copy()
new_dict
# Out:
# {'age': '25', 'height': 1.8, 'name': 'Yuri'}

# %%
#Creating a DataFrame from adictionary
#Lists used this example
states = ['California', 'Texas', 'Florida', 'New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
#Storing lists within a dictionary
dict_states = {'States':states, 'Population': population}

# %%
#Creating the DataFrame
import pandas as pd
df_population = pd.DataFrame(dict_states)
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %%
#reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
#Show first 5 rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity  ... reading score writing score
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [5 rows x 8 columns]

# %%
#getting acess tothe shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
#display n rows
pd.set_option('Display.max_rows', 1000)
df_exams
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# 7      male        group B  ...            43            39
# 8      male        group D  ...            64            67
# 9    female        group B  ...            60            50
# 10     male        group C  ...            54            52
# 11     male        group D  ...            52            43
# 12   female        group B  ...            81            73
# 13     male        group A  ...            72            70
# 14   female        group A  ...            53            58
# ...

# %%
#getting acess to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
#getting acess to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#getting acess to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#data types of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#describinf basic statistic of the dataFrame
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#obtainun the lenght os the dataframe(number of rows)
len(df_exams)
# Out:
# 1000

# %%
#obtainun the hightest index os the dataframe
max(df_exams.index)
# Out:
# 999

# %%
#obtainun the lowest index os the dataframe
min(df_exams.index)
# Out:
# 0

# %%
#obtaining the data type

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
#rounding the values of the dataset
round(df_exams, 2)
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# 5    female        group B  ...            83            78
# 6    female        group B  ...            95            92
# 7      male        group B  ...            43            39
# 8      male        group D  ...            64            67
# 9    female        group B  ...            60            50
# 10     male        group C  ...            54            52
# 11     male        group D  ...            52            43
# 12   female        group B  ...            81            73
# 13     male        group A  ...            72            70
# 14   female        group A  ...            53            58
# ...

# %%
#selecting one column os a dataframe
#sintax 1 
#select a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
#check out the data of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
#series : attributes and methods
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
#Syntex 2 to select a column
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
#select a columns with. (pitfalls)
df_exams.math score
# Out:
#   File "<ipython-input-40-3c37481ab56a>", line 2
#     df_exams.math score
#                       ^
# SyntaxError: invalid syntax

# %%
#select the same column using []
df_exams ['math score']
# Out:
# 0       72
# 1       69
# 2       90
# 3       47
# 4       76
# 5       71
# 6       88
# 7       40
# 8       64
# 9       38
# 10      58
# 11      40
# 12      65
# 13      78
# 14      50
# 15      69
# 16      88
# 17      18
# 18      46
# 19      54
# 20      66
# 21      65
# 22      44
# 23      69
# 24      74
# 25      73
# 26      69
# 27      67
# 28      70
# 29      62
# 30      69
# 31      63
# 32      56
# 33      40
# 34      97
# 35      81
# 36      74
# 37      50
# 38      75
# 39      57
# 40      55
# 41      58
# 42      53
# 43      59
# 44      50
# 45      65
# 46      55
# 47      66
# 48      57
# 49      82
# 50      53
# 51      77
# 52      53
# 53      88
# 54      71
# 55      33
# 56      82
# 57      52
# 58      58
# 59       0
# 60      79
# 61      39
# 62      62
# 63      69
# 64      59
# 65      67
# 66      45
# 67      60
# 68      61
# 69      39
# 70      58
# 71      63
# 72      41
# 73      61
# 74      49
# 75      44
# ...

# %% [markdown]
# SELECTING TWO OR MORE COLUMNS

# %%
#select 2 columns using [[]]
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# 5    female          71
# 6    female          88
# 7      male          40
# 8      male          64
# 9    female          38
# 10     male          58
# 11     male          40
# 12   female          65
# 13     male          78
# 14   female          50
# 15   female          69
# 16     male          88
# 17   female          18
# 18     male          46
# 19   female          54
# 20     male          66
# 21   female          65
# 22     male          44
# 23   female          69
# 24     male          74
# 25     male          73
# 26     male          69
# 27   female          67
# 28     male          70
# 29   female          62
# 30   female          69
# 31   female          63
# 32   female          56
# 33     male          40
# 34     male          97
# 35     male          81
# 36   female          74
# ...

# %%
#check out the data type of the selection
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
#select 2 or more columns using []
df_exams[['gender', 'math score', 'reading score','writing score']]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# 5    female          71             83             78
# 6    female          88             95             92
# 7      male          40             43             39
# 8      male          64             64             67
# 9    female          38             60             50
# 10     male          58             54             52
# 11     male          40             52             43
# 12   female          65             81             73
# 13     male          78             72             70
# 14   female          50             53             58
# 15   female          69             75             78
# ...

# %% [markdown]
# ADD A NEW COLUMN

# %%
#1. Adding a new column with a scalar value
#adding new column to dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity  ... writing score language score
# 0    female        group B  ...            74             70
# 1    female        group C  ...            88             70
# 2    female        group B  ...            93             70
# 3      male        group A  ...            44             70
# 4      male        group C  ...            75             70
# 5    female        group B  ...            78             70
# 6    female        group B  ...            92             70
# 7      male        group B  ...            39             70
# 8      male        group D  ...            67             70
# 9    female        group B  ...            50             70
# 10     male        group C  ...            52             70
# 11     male        group D  ...            43             70
# 12   female        group B  ...            73             70
# 13     male        group A  ...            70             70
# ...

# %%
#1.2 Adding a new column with a array 
#creting a array of 1000 elements
import numpy as np
language_score = np.arange(0,1000)

# %%
#length pf the array
len(language_score)
# Out:
# 1000

# %%
#create random integer numbers between 1 and 100
int_language_score = np.random.randint(1,100, size = 1000)

# %%
#min value and the high value exclusive
